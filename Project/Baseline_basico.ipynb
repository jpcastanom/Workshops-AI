# %%
import pandas as pd
from torchvision import datasets, transforms

# %%
# Usenlo para instalar el dataset de Kaggle en su entorno de trabajo. Idealmente en la carpeta de Project, yo lo puse en git ignore para que no se suba.
'''
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rashikrahmanpritom/plant-disease-recognition-dataset")

print("Path to dataset files:", path)
'''
# Out:
# ...
# 100%|██████████| 1.25G/1.25G [00:43<00:00, 31.0MB/s]
# Extracting files...
# Path to dataset files: C:\Users\USUARIO\.cache\kagglehub\datasets\rashikrahmanpritom\plant-disease-recognition-dataset\versions\1

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Buscar qué tamaño usar
    transforms.ToTensor(),
])

train_path = "Plant_disease_recognition_dataset/Train/Train"
test_path = "Plant_disease_recognition_dataset/Test/Test"

train_dataset = datasets.ImageFolder(
    root=train_path
    #,transform=transforms
)

test_dataset = datasets.ImageFolder(
    root=test_path
    #,transform=transform
)

print(train_dataset.classes)
print(len(train_dataset), len(test_dataset))
# Out:
# ['Healthy', 'Powdery', 'Rust']
# 1322 150

# %%
train_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1322
#     Root location: Plant_disease_recognition_dataset/Train/Train
